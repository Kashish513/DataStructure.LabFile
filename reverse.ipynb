# %%
def reverse_string_using_stack(s):
    stack = []

    for char in s:
        stack.append(char)

    reversed_string = ""

    while stack:
        reversed_string += stack.pop()

    return reversed_string

string = input("Enter a string to reverse: ")
result = reverse_string_using_stack(string)
print("Reversed String:", result)
# Out:
# Enter a string to reverse:  Data Structure
# Reversed String: erutcurtS ataD
